# %% [markdown]
# <a href="https://colab.research.google.com/github/yanil-03/Machine-Learning/blob/main/Apriori_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #What is Apriori Algorithm?
# Apriori Algorithm is a frequent pattern mining algorithm that is used in association rule learning.
# It is wiely used in market basket analysis to find associations and relationships between items in large datasets of transactions

# %% [markdown]
# #How Apriori Algorithm works?
# 1. It identify all frequent individual items in a dataset.
# 2. Then it extend them to larger item sets as long as those item sets appear frequently enough in the data.
# 3. Then it use the frequent item sets to generate association rules.

# %% [markdown]
# #Key-Metrics
# 1. *Support* ->  How frequently an item set appears in the data set. It measures the how popular rule is.
#
#   `(support of A to B =  transactions containing  A U B / total transactions)`
#
# 2. *Confidence* ->  How often item in b appear in transaction that contain a. It measures the strength of implimentation . High confidence means when A occurs B often occurs too.
#
#   `(confidence of A to B = Support of A U B / support of A)`
#
# 3. *Lift* -> How much more often A and B occur together than expected if they were statistically independent.
#
#   `(Lift of A to B = Confidence of A to B / Support of B)`
#
#     If lift > 1, it means positive corelation
#
#     If lift = 1, it means no corelation
#
#     If lift < 1, means negative corelation

# %%
# TRANS_ID  ITEMS_BOUGHT

# 1          milk and bread
# 2          milk bread and butter
# 3          bread and butter
# 4          milk and butter
# 5          Bread

# lets analyze the association rule for milk to butter

# Support of milk to butter ->  2/5 -> 40% chance of getting milk and butter together

# Confidence -> Along all transaction of milk how many also have butter
# confidence of milk to butter --> 2/3 = 0.67 -> 67%

# Lift -> How much more likely someone isto buy butter. If they buy milk compared to just buying butter by itself.
# Support of butter  = 3/5 = .6 -> 60%
# Lift of milk to butter = confidence / support of butter = 0.67 / 0.6 = 1.11

# Lift = 1.11, means milk buyers are 11% more likely to buy butter than general customers.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('market_basket.csv', header= None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
# !pip install apyori

# %%
# Data Processing
transactions = []
for i in range(0,7501):
    transactions.append([str(df.values[i,j]) for j in range(0,20)])

#Training the dataset
from apyori import apriori
rules = apriori(transactions ,
              min_support = 0.003 ,     #(3items * 7 days in week)/(Total Rows in dataset 7501)
              min_confidence = 0.2 ,
              min_lift = 3 ,
              min_length = 2)

#Visualizing the results
a = list(rules)
result = [list(a[i][0]) for i in range(0 , len(a))]

# %%
df.shape
# Out:
# (7501, 20)

# %%
result
# Out:
# [['light cream', 'chicken'],
#  ['escalope', 'mushroom cream sauce'],
#  ['escalope', 'pasta'],
#  ['fromage blanc', 'honey'],
#  ['ground beef', 'herb & pepper'],
#  ['tomato sauce', 'ground beef'],
#  ['light cream', 'olive oil'],
#  ['whole wheat pasta', 'olive oil'],
#  ['pasta', 'shrimp'],
#  ['avocado', 'spaghetti', 'milk'],
#  ['cake', 'burgers', 'milk'],
#  ['turkey', 'burgers', 'chocolate'],
#  ['turkey', 'burgers', 'milk'],
#  ['cake', 'tomatoes', 'frozen vegetables'],
#  ['cereals', 'ground beef', 'spaghetti'],
#  ['milk', 'ground beef', 'chicken'],
#  ['nan', 'light cream', 'chicken'],
#  ['milk', 'olive oil', 'chicken'],
#  ['olive oil', 'spaghetti', 'chicken'],
#  ['shrimp', 'frozen vegetables', 'chocolate'],
#  ['ground beef', 'herb & pepper', 'chocolate'],
#  ['milk', 'soup', 'chocolate'],
#  ['cooking oil', 'ground beef', 'spaghetti'],
#  ['eggs', 'ground beef', 'herb & pepper'],
#  ['red wine', 'eggs', 'spaghetti'],
#  ['nan', 'escalope', 'mushroom cream sauce'],
#  ['nan', 'escalope', 'pasta'],
#  ['french fries', 'ground beef', 'herb & pepper'],
#  ['fromage blanc', 'honey', 'nan'],
#  ['green tea', 'tomatoes', 'frozen vegetables'],
#  ['ground beef', 'spaghetti', 'frozen vegetables'],
#  ['olive oil', 'frozen vegetables', 'milk'],
#  ['soup', 'frozen vegetables', 'milk'],
#  ['tomatoes', 'frozen vegetables', 'milk'],
#  ['shrimp', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'frozen vegetables', 'olive oil'],
#  ['spaghetti', 'frozen vegetables', 'shrimp'],
#  ['tomatoes', 'frozen vegetables', 'shrimp'],
#  ['spaghetti', 'frozen vegetables', 'tomatoes'],
#  ['spaghetti', 'grated cheese', 'ground beef'],
#  ['green tea', 'ground beef', 'tomatoes'],
#  ['milk', 'ground beef', 'herb & pepper'],
#  ['mineral water', 'ground beef', 'herb & pepper'],
#  ['nan', 'ground beef', 'herb & pepper'],
#  ['ground beef', 'spaghetti', 'herb & pepper'],
#  ['olive oil', 'ground beef', 'milk'],
#  ['ground beef', 'soup', 'milk'],
#  ['nan', 'tomato sauce', 'ground beef'],
#  ['ground beef', 'spaghetti', 'pepper'],
#  ['ground beef', 'spaghetti', 'shrimp'],
#  ['tomato sauce', 'ground beef', 'spaghetti'],
#  ['light cream', 'spaghetti', 'mineral water'],
#  ['nan', 'light cream', 'olive oil'],
#  ['olive oil', 'shrimp', 'milk'],
#  ['olive oil', 'soup', 'milk'],
#  ['olive oil', 'spaghetti', 'milk'],
#  ['tomatoes', 'soup', 'milk'],
#  ['whole wheat pasta', 'spaghetti', 'milk'],
#  ['olive oil', 'soup', 'mineral water'],
#  ['olive oil', 'whole wheat pasta', 'mineral water'],
#  ['nan', 'whole wheat pasta', 'olive oil'],
#  ['nan', 'pasta', 'shrimp'],
#  ['pancakes', 'spaghetti', 'olive oil'],
#  ['tomatoes', 'spaghetti', 'olive oil'],
#  ['whole wheat rice', 'spaghetti', 'tomatoes'],
#  ['nan', 'avocado', 'spaghetti', 'milk'],
#  ['nan', 'cake', 'burgers', 'milk'],
#  ['nan', 'turkey', 'burgers', 'chocolate'],
#  ['nan', 'turkey', 'burgers', 'milk'],
#  ['nan', 'cake', 'tomatoes', 'frozen vegetables'],
#  ['nan', 'cereals', 'ground beef', 'spaghetti'],
#  ['milk', 'ground beef', 'nan', 'chicken'],
#  ['milk', 'olive oil', 'nan', 'chicken'],
#  ['nan', 'olive oil', 'spaghetti', 'chicken'],
#  ['eggs', 'mineral water', 'ground beef', 'chocolate'],
#  ['mineral water', 'ground beef', 'frozen vegetables', 'chocolate'],
#  ['ground beef', 'spaghetti', 'frozen vegetables', 'chocolate'],
#  ['milk', 'mineral water', 'frozen vegetables', 'chocolate'],
#  ['milk', 'spaghetti', 'frozen vegetables', 'chocolate'],
#  ['shrimp', 'mineral water', 'frozen vegetables', 'chocolate'],
#  ['nan', 'shrimp', 'frozen vegetables', 'chocolate'],
#  ['nan', 'ground beef', 'herb & pepper', 'chocolate'],
#  ['milk', 'nan', 'soup', 'chocolate'],
#  ['olive oil', 'mineral water', 'spaghetti', 'chocolate'],
#  ['shrimp', 'mineral water', 'spaghetti', 'chocolate'],
#  ['nan', 'cooking oil', 'ground beef', 'spaghetti'],
#  ['eggs', 'mineral water', 'frozen vegetables', 'milk'],
#  ['nan', 'eggs', 'ground beef', 'herb & pepper'],
#  ['nan', 'eggs', 'spaghetti', 'red wine'],
#  ['nan', 'french fries', 'ground beef', 'herb & pepper'],
#  ['milk', 'mineral water', 'spaghetti', 'frozen smoothie'],
#  ['nan', 'green tea', 'tomatoes', 'frozen vegetables'],
#  ['mineral water', 'ground beef', 'frozen vegetables', 'milk'],
#  ['ground beef', 'spaghetti', 'frozen vegetables', 'milk'],
#  ['ground beef', 'spaghetti', 'frozen vegetables', 'mineral water'],
#  ['nan', 'ground beef', 'spaghetti', 'frozen vegetables'],
#  ['olive oil', 'mineral water', 'frozen vegetables', 'milk'],
#  ['mineral water', 'soup', 'frozen vegetables', 'milk'],
#  ['mineral water', 'spaghetti', 'frozen vegetables', 'milk'],
#  ['nan', 'olive oil', 'frozen vegetables', 'milk'],
#  ['nan', 'soup', 'frozen vegetables', 'milk'],
#  ['nan', 'tomatoes', 'frozen vegetables', 'milk'],
#  ['nan', 'shrimp', 'frozen vegetables', 'mineral water'],
#  ['shrimp', 'spaghetti', 'frozen vegetables', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'frozen vegetables', 'mineral water'],
#  ['nan', 'spaghetti', 'frozen vegetables', 'olive oil'],
#  ['nan', 'spaghetti', 'frozen vegetables', 'shrimp'],
#  ['nan', 'tomatoes', 'frozen vegetables', 'shrimp'],
#  ['nan', 'spaghetti', 'frozen vegetables', 'tomatoes'],
#  ['nan', 'spaghetti', 'grated cheese', 'ground beef'],
#  ['nan', 'green tea', 'ground beef', 'tomatoes'],
#  ['milk', 'ground beef', 'nan', 'herb & pepper'],
#  ['nan', 'mineral water', 'ground beef', 'herb & pepper'],
#  ['nan', 'ground beef', 'spaghetti', 'herb & pepper'],
#  ['mineral water', 'ground beef', 'spaghetti', 'milk'],
#  ['nan', 'olive oil', 'ground beef', 'milk'],
#  ['nan', 'ground beef', 'soup', 'milk'],
#  ['olive oil', 'ground beef', 'spaghetti', 'mineral water'],
#  ['pancakes', 'ground beef', 'spaghetti', 'mineral water'],
#  ['tomatoes', 'ground beef', 'spaghetti', 'mineral water'],
#  ['nan', 'ground beef', 'spaghetti', 'pepper'],
#  ['nan', 'ground beef', 'spaghetti', 'shrimp'],
#  ['nan', 'tomato sauce', 'ground beef', 'spaghetti'],
#  ['nan', 'light cream', 'spaghetti', 'mineral water'],
#  ['olive oil', 'mineral water', 'spaghetti', 'milk'],
#  ['tomatoes', 'mineral water', 'spaghetti', 'milk'],
#  ['nan', 'olive oil', 'shrimp', 'milk'],
#  ['nan', 'olive oil', 'soup', 'milk'],
#  ['nan', 'olive oil', 'spaghetti', 'milk'],
#  ['nan', 'tomatoes', 'soup', 'milk'],
#  ['nan', 'spaghetti', 'whole wheat pasta', 'milk'],
#  ['nan', 'olive oil', 'soup', 'mineral water'],
#  ['nan', 'olive oil', 'whole wheat pasta', 'mineral water'],
#  ['nan', 'pancakes', 'spaghetti', 'olive oil'],
#  ['nan', 'tomatoes', 'spaghetti', 'olive oil'],
#  ['nan', 'spaghetti', 'whole wheat rice', 'tomatoes'],
#  ['eggs', 'nan', 'ground beef', 'mineral water', 'chocolate'],
#  ['nan', 'ground beef', 'frozen vegetables', 'mineral water', 'chocolate'],
#  ['spaghetti', 'nan', 'ground beef', 'frozen vegetables', 'chocolate'],
#  ['nan', 'frozen vegetables', 'milk', 'mineral water', 'chocolate'],
#  ['spaghetti', 'nan', 'frozen vegetables', 'milk', 'chocolate'],
#  ['nan', 'frozen vegetables', 'shrimp', 'mineral water', 'chocolate'],
#  ['olive oil', 'spaghetti', 'nan', 'mineral water', 'chocolate'],
#  ['spaghetti', 'nan', 'shrimp', 'mineral water', 'chocolate'],
#  ['eggs', 'nan', 'milk', 'frozen vegetables', 'mineral water'],
#  ['frozen smoothie', 'spaghetti', 'nan', 'milk', 'mineral water'],
#  ['nan', 'milk', 'ground beef', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'nan', 'ground beef', 'frozen vegetables', 'milk'],
#  ['spaghetti', 'nan', 'ground beef', 'frozen vegetables', 'mineral water'],
#  ['olive oil', 'nan', 'milk', 'frozen vegetables', 'mineral water'],
#  ['soup', 'nan', 'milk', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'nan', 'milk', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'nan', 'frozen vegetables', 'shrimp', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'nan', 'frozen vegetables', 'mineral water'],
#  ['spaghetti', 'nan', 'milk', 'ground beef', 'mineral water'],
#  ['olive oil', 'spaghetti', 'nan', 'ground beef', 'mineral water'],
#  ['pancakes', 'spaghetti', 'nan', 'ground beef', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'nan', 'ground beef', 'mineral water'],
#  ['olive oil', 'spaghetti', 'nan', 'milk', 'mineral water'],
#  ['tomatoes', 'spaghetti', 'nan', 'milk', 'mineral water']]
