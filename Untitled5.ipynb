# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np

# %%
# Funtion Transformer --->
# dataset ---> custom operation apply ---> use of function transformer

# Function transformer ---> object create ---> as an argument pass function(pre-defined or custom)
# logic ---> apply data set

# %%
# create a dataset
X = np.array([[1, 2],[3 , 4]])
print(X)

# define the transformation function
log_transform = FunctionTransformer(np.log1p)

# apply the transformation to the dataset
X_transformed = log_transform.transform(X)

# print the transformed dataset
print(X_transformed)
# Out:
# [[1 2]
#  [3 4]]
# [[0.69314718 1.09861229]
#  [1.38629436 1.60943791]]

# %%
# create a dataset
X = np.array([[1, 2],[3 , 4]])
print(X)

# define a custom feature engineering function
def squ(X):
  return np.hstack((X, X**2))

# create a FunctionTransformer to apply the custom function
custom_transform = FunctionTransformer(squ)

# apply the transformation to the dataset
X_transformed = custom_transform.transform(X)

# print the transformed dataset
print(X_transformed)
# Out:
# [[1 2]
#  [3 4]]
# array([[ 1,  2,  1,  4],
#        [ 3,  4,  9, 16]])

# %%
# PipeLine ---> container steps of process but sequentailly.

# column transfirmer =----> 1 step output will not the 2 step input
# Pipeline --->  1 step output will be the 2 step input

# Data ---> x, y --->

# %%
df = pd.read_csv('/content/covid_toy.csv')
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns=['has_covid'])
y = df['has_covid']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
#Define the column that need to be processed
categorical_features = ['gender', 'city']
numeric_features = ['age','fever']

# %%
# Create transformers
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

#combine Transformers
preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# %%
n =5
for i in range(n, 0, -1):
  print(" "*(n-i) + "*" * i)

for j in range(2, n+1):
  print(" "*(n-j) + "*" * j)
# Out:
# *****
#  ****
#   ***
#    **
#     *
#    **
#   ***
#  ****
# *****

# %%
n = 5
for i in range(n, 0, -1):
  for j in range(i, 0, -1):
    print(j, end=" ")
  print()
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
text = "aabcdeef"
ans=[]
seen = []
counter = 0
for i in text:
  if i not in seen:
    for j in text:
      if i==j:
        counter = counter + 1
    ans.append(counter)
  seen.append(i)

  counter = 0
print(ans)
# Out:
# [2, 1, 1, 1, 2, 1]

# %%
get_budget = [
    {'name':'John', 'age':21, 'budget':23000},
    {'name':'Steve', 'age':32, 'budget':40000},
    {'name':'Martin', 'age':16, 'budget':2700}]

def budget_sum(d):
  total = 0
  for data in d:
    total +=data['budget']
  return total

budget_sum(get_budget)
# Out:
# 65700
